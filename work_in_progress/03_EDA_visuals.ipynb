# %% [markdown]
# # Veteran Characteristic Exploration
# ---
# Lets first begin with logisitc regression to find traits that identify veterans.

# %%
# Import need libraries
import pandas as pd
import scipy as sc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import ComplementNB
import missingno as ms

import os
import time

# %%
# Read in dataset
vet_1 = pd.read_csv("../working_data/vets_1yr_clean.csv")

# %%
'''Additional viewing options'''
# This code sets the notebook to display maximum columns.  Uncomment it to see trunacted view
pd.set_option('display.max_columns', len(vet_1))  

# This resets the view to a truncated output
#pd.reset_option('display.max_rows')

# %%
# Evaluate coefficients
vet_1.columns
# Out:
# Index(['SERIALNO', 'PINCP_adj', 'PERNP_adj', 'WAGP_adj', 'SSIP_adj', 'SSP_adj',
#        'RETP_adj', 'PAP_adj', 'OIP_adj', 'INTP_adj',
#        ...
#        'VPS_6', 'VPS_7', 'VPS_8', 'VPS_9', 'VPS_10', 'VPS_11', 'VPS_12',
#        'VPS_13', 'VPS_14', 'VPS_15'],
#       dtype='object', length=139)

# %%
# Create initial visualizations of veteran data
top_corr = vet_1.corr()
top_corr_features = top_corr.index[abs(top_corr['HINS6'])>0.4]
plt.figure(figsize=(12,10))
g = sns.heatmap(vet_1[top_corr_features].corr(),annot=True,cmap="rainbow")

# %%
# Create heatmap of correlations above .5
# Building a heat map of variables that have correlation above .5 with sales price.
top_corr = vet_1.corr()
top_corr_features = top_corr.index[abs(top_corr["HINS6"])<.05]
plt.figure(figsize=(12,10))
g = sns.heatmap(vet_1[top_corr_features].corr(),annot=True,cmap="rainbow");

# %%
# Hist plot of data
work = ['AGEP', 'PINCP_adj', 'COW', 'SCHL', 'HINS6']

g = sns.pairplot(vet_1, 
                 hue='HINS6', 
                 palette='husl', 
                 vars=work, 
                 corner=True, 
                 kind='reg',
                  );
# Out:
# /Users/joshkuehl/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/joshkuehl/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Define dependent and independent variables

# Train, test, split

# Scale data

# %%
# Instantiate model or pipeline

# Fit model

# Determine predicitions

# %%
# Evaluate coefficients
